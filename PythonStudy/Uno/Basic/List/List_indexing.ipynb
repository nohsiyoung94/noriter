# %%
# Out:
# 1

# %%
a

# %%
a= [1,2,3]
print(a)
print(a[0])
print(a[0]+a[2])
print(a[0])
# Out:
# [1, 2, 3]
# 1
# 4
# 1

# %%
a=[1,2,3,['a','b','c',['가','나']],4,'4']
print(a)
print(a[0], a[3])
print(a[-3][2])
print(a[-3][3][1])
# Out:
# [1, 2, 3, ['a', 'b', 'c', ['가', '나']], 4, '4']
# 1 ['a', 'b', 'c', ['가', '나']]
# c
# 나

# %%
a=[1,2,3,4,5]
a[0:2]
print(a[0:2])
# Out:
# [1, 2]

# %%
a = "12345"
a[0:2]
print(a)
print(a[0:2])
# Out:
# 12345
# 12

# %%
a=[1,2,3,['a','b','c',['가','나']],4,'4']
b = a[2:5]
c = b[1][3:4]
print(b)
print(c)
d = a[2:5][1][3][:1]
print(d)
# Out:
# [3, ['a', 'b', 'c', ['가', '나']], 4]
# [['가', '나']]
# ['가']

# %%
a = [1,2,3]
b = [4,5,6]
a + b
print(a + b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3]
print(a * 3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a = [1,2,3]
len(a[1:2])
# Out:
# 1

# %%
a = [1,2,3]
b = str(a[2])+"hi"
print(b)
# Out:
# 3hi

# %%
a = [1,2,3]
a[2] = 4
print(a)
